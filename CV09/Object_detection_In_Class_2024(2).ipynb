# %% [markdown]
# # Thực hành: Phát hiện đối tượng YOLO
# Trong bài này ta sẽ thực hành bài toán phát hiện quả dừa trên băng chuyền bằng mô hình YOLO

# %% [markdown]
# # 1. Cài đặt

# %% [markdown]
# Tải YOLO

# %%
# !git clone https://github.com/ultralytics/yolov3
# Out:
# Cloning into 'yolov3'...
# remote: Enumerating objects: 11820, done.
# remote: Counting objects: 100% (1742/1742), done.
# remote: Compressing objects: 100% (816/816), done.
# remote: Total 11820 (delta 1252), reused 1315 (delta 925), pack-reused 10078 (from 1)
# Receiving objects: 100% (11820/11820), 10.35 MiB | 5.49 MiB/s, done.
# Resolving deltas: 100% (8051/8051), done.

# %%
#############
# 1 line of code here
#############
# Out:
# Cloning into 'yolov3'...
# remote: Enumerating objects: 10034, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 10034 (delta 4), reused 9 (delta 3), pack-reused 10017
# Receiving objects: 100% (10034/10034), 9.36 MiB | 14.32 MiB/s, done.
# Resolving deltas: 100% (6762/6762), done.

# %%
cd yolov3/
# Out:
# /content/yolov3

# %% [markdown]
# Cài đặt các thư viện cần thiết sử dụng pip install requrement.txt

# %%
#############
# 1 line of code here
# !pip install -qr requirements.txt
#############
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 874.1/874.1 kB 38.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.1 MB/s eta 0:00:00

# %% [markdown]
# # 2. Gán nhãn dữ liệu
# Làm quen với gán nhãn dữ liệu bằng công cụ LabelImg
# 1. Cài đặt công cụ LabelImg: https://github.com/tzutalin/labelImg
# 2. Chỉnh sửa predefined_classes.txt trong thư mục labelimg/data: Xoá nội dung 15 class có sẵn và thay bằng coconut
# 3. Mở labelimg: python3 labelimg
# 4. Chọn thư mục samples, chọn định dạng YOLO và thực hiện đánh nhãn

# %% [markdown]
# # 3. Chuẩn bị dữ liệu
#
# **Mô tả**: Trong thư mục datasets chứa bộ dữ liệu sử dụng trong bài thực hành này. Trong thư mục này chứa thư mục con **images** gồm toàn bộ ảnh dữ liệu; file **all_annotations.txt** chứa nhãn bounding box của toàn bộ ảnh (được đánh nhãn sẵn từ trước). File **all_annotations.txt** gồm nhiều dòng, mỗi dòng có format như sau:
#
# _image_path x1,y1,u1,v1,c1 x2,y2,u2,v2,c2 ... xn, yn, un, vn, cn_
#
# Trong đó (xi, yi) là tọa độ góc trên trái của đối tượng thứ i, (ui, vi) là tọa độ góc trên phải của đối tượng thứ i, ci là lớp của đối tượng thứ i. Trong bài thực hành này ta chỉ có một lớp dữ liệu duy nhất.
#
#
# **Mô tả format annotation mới**: Mỗi ảnh ta sẽ có 1 file .txt lưu thông tin các bounding box. File .txt này có định dạng như sau:
#
# *   Mỗi bounding box một dòng trong file
# *   Format của từng dòng là: class x_center y_center width height
# *   Cần normalize x_center y_center width height về range [0, 1]
# *   class được đánh số bắt đầu từ 0
#
# **Công việc cần thực hiện**:
#
# 1.   Tạo thư mục datasets/labels chứa toàn bộ các file .txt (mỗi ảnh trong thư mục datasets/images ứng với 1 file .txt trong thư mục datasets/labels) theo mô tả ở trên)
# 2.   Tham khảo file yolov3/data/coco.yaml, tạo file yolov3/data/coconut.yaml ứng với dataset ta vừa xử lý

# %% [markdown]
# Mount Google Drive

# %%
#############
# your code here
#############
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Upload datasets.zip và unzip
#
# **Lưu ý:** Trong file zip sẵn chỉ có 20 ảnh. Nếu muốn tải full dữ liệu, các bạn có thể tải tại link sau: <a href="https://u.pcloud.link/publink/show?code=XZp1BhVZmloQdDfGGHFnNfoK7gX2vy66NlrX&fbclid=IwY2xjawFgZ1FleHRuA2FlbQIxMAABHTgHKueaW_1VSEELuOk6RSmPuJ57dld_msT0EKG2GVTOGaWah78rqHuXJg_aem_z34JWfq4mptE_3KBbeNKtw">https://u.pcloud.link/publink/show?code=XZp1BhVZmloQdDfGGHFnNfoK7gX2vy66NlrX&fbclid=IwY2xjawFgZ1FleHRuA2FlbQIxMAABHTgHKueaW_1VSEELuOk6RSmPuJ57dld_msT0EKG2GVTOGaWah78rqHuXJg_aem_z34JWfq4mptE_3KBbeNKtw</a>

# %%
# !ls
# Out:
# benchmarks.py	 data	     LICENSE	     README.zh-CN.md   tutorial.ipynb
# CITATION.cff	 detect.py   models	     requirements.txt  utils
# classify	 export.py   pyproject.toml  segment	       val.py
# CONTRIBUTING.md  hubconf.py  README.md	     train.py

# %%
cd /content/
# Out:
# /content

# %%
# !unzip datasets
# Out:
# Archive:  datasets.zip
#    creating: datasets/
#   inflating: datasets/all_annotations.txt
#   inflating: datasets/images.zip
#   inflating: datasets/labels.zip

# %%
# !unzip 'datasets/images.zip'
# !unzip 'datasets/labels.zip'
# Out:
# Archive:  datasets/images.zip
#    creating: images/
#   inflating: images/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/images/
#   inflating: __MACOSX/images/._.DS_Store
#   inflating: images/8.png
#   inflating: __MACOSX/images/._8.png
#   inflating: images/9.png
#   inflating: __MACOSX/images/._9.png
#   inflating: images/14.png
#   inflating: __MACOSX/images/._14.png
#   inflating: images/15.png
#   inflating: __MACOSX/images/._15.png
#   inflating: images/17.png
#   inflating: __MACOSX/images/._17.png
#   inflating: images/16.png
#   inflating: __MACOSX/images/._16.png
#   inflating: images/12.png
#   inflating: __MACOSX/images/._12.png
#   inflating: images/13.png
#   inflating: __MACOSX/images/._13.png
#   inflating: images/11.png
#   inflating: __MACOSX/images/._11.png
#   inflating: images/10.png
#   inflating: __MACOSX/images/._10.png
#   inflating: images/20.png
#   inflating: __MACOSX/images/._20.png
#   inflating: images/18.png
#   inflating: __MACOSX/images/._18.png
#   inflating: images/19.png
#   inflating: __MACOSX/images/._19.png
#   inflating: images/4.png
#   inflating: __MACOSX/images/._4.png
#   inflating: images/5.png
#   inflating: __MACOSX/images/._5.png
#   inflating: images/7.png
#   inflating: __MACOSX/images/._7.png
#   inflating: images/6.png
#   inflating: __MACOSX/images/._6.png
#   inflating: images/2.png
#   inflating: __MACOSX/images/._2.png
#   inflating: images/3.png
#   inflating: __MACOSX/images/._3.png
#   inflating: images/1.png
#   inflating: __MACOSX/images/._1.png
# Archive:  datasets/labels.zip
#    creating: labels/
#   inflating: labels/.DS_Store
#    creating: __MACOSX/labels/
#   inflating: __MACOSX/labels/._.DS_Store

# %%
# Bước 1: Sinh file .txt chứa thông tin bounding box cho từng ảnh
import os
import cv2

IMAGE_FOLDER = '/content/datasets/images/'
ANNOTATION_FILE = '/content/datasets/all_annotations.txt'
LABEL_FOLDER = '/content/datasets/labels/'

if not os.path.isdir(LABEL_FOLDER):
  os.mkdir(LABEL_FOLDER)

with open(ANNOTATION_FILE) as f:
  for line in f:
    data = line.split()

    image_fp = data[0]
    image_idx = image_fp.split('/')[-1].split('.')[0]
    image = cv2.imread(image_fp)
    if image is None:
      continue
    height, width = image.shape[:2]

    normalized_bbox = []
    for bbox in data[1:]:
      x, y, u, v, cls = [int(a) for a in bbox.split(',')]
      x_center = (x + u) / 2 / width
      y_center = (y + v) / 2 / height
      box_width = (u - x) / width
      box_height =  (v - y) / height

      normalized_bbox.append((cls, x_center, y_center, box_width, box_height))

    with open(os.path.join(LABEL_FOLDER, image_idx + '.txt'), 'w') as g:
      for bbox in normalized_bbox:
        g.write(' '.join([str(s) for s in bbox]) + '\n')

# %%
cd yolov3/data
# Out:
# /content/yolov3/data

# %%
cp coco.yaml coconut.yaml

# %%
# Bước 2: Tạo file coconut.yaml
# cd yolov3/data
# cp coco.yaml coconut.yaml

# Chỉnh sửa yolov3/data/coconut.yaml với nội dung như trong phần comment sau:

'''
path: ../datasets
train: images/
val: images/

nc: 1

names: ['coconut']
'''
# Out:
#   File "<ipython-input-14-083b56b11b6b>", line 2
#     cd yolov3/data
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 4. Huấn luyện mô hình

# %%
cd /content/yolov3
# Out:
# /content/yolov3

# %% [markdown]
# ## Cách 1: Finetune
#
# Ta sẽ thử fine-tune model với pretrained có sẵn, các tham số theo như mặc định (tham khảo file yolov3/train.py), đây là cách chúng ta luôn thử đầu tiên với một bài toán mới. Bạn có thể thay đổi số epoch để rút ngắn thời gian training. Sau khi kết thúc quá trình training, hãy nhìn vào phần log cuối cùng để xác định vị trí lưu weights đã train.

# %%
# !python train.py --img 416 --batch 16 --epochs 20 --data data/coconut.yaml --weights yolov3.pt
# Out:
# 2024-09-25 09:46:56.241412: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-25 09:46:56.261379: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-25 09:46:56.267332: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov3.pt, cfg=, data=data/coconut.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv3 is out of date by 2852 commits. Use 'git pull ultralytics master' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv3 🚀 v9.6.0-227-g8882dca3 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv3 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
#
#                  from  n    params  module                                  arguments
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 1]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     20672  models.common.Bottleneck                [64, 64]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    164608  models.common.Bottleneck                [128, 128]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  8   2627584  models.common.Bottleneck                [256, 256]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  8  10498048  models.common.Bottleneck                [512, 512]
#   9                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#  10                -1  4  20983808  models.common.Bottleneck                [1024, 1024]
#  11                -1  1   5245952  models.common.Bottleneck                [1024, 1024, False]
#  12                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  13                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 1]
#  14                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  15                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 1]
#  16                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  17                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  18           [-1, 8]  1         0  models.common.Concat                    [1]
#  19                -1  1   1377792  models.common.Bottleneck                [768, 512, False]
#  20                -1  1   1312256  models.common.Bottleneck                [512, 512, False]
#  21                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  22                -1  1   1180672  models.common.Conv                      [256, 512, 3, 1]
#  23                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  24                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  25           [-1, 6]  1         0  models.common.Concat                    [1]
#  26                -1  1    344832  models.common.Bottleneck                [384, 256, False]
#  27                -1  2    656896  models.common.Bottleneck                [256, 256, False]
#  28      [27, 22, 15]  1    457725  models.yolo.Detect                      [80, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [256, 512, 1024]]
# Model summary: 262 layers, 61949149 parameters, 61949149 gradients, 156.6 GFLOPs
#
# Transferred 439/439 items from yolov3.pt
# /content/yolov3/models/common.py:860: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# WARNING ⚠️ NMS time limit 0.550s exceeded
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 72 weight(decay=0.0), 75 weight(decay=0.0005), 75 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/datasets/labels... 20 images, 0 backgrounds, 0 corrupt: 100% 20/20 [00:00<00:00, 350.55it/s]
# train: New cache created: /content/datasets/labels.cache
# val: Scanning /content/datasets/labels.cache... 20 images, 0 backgrounds, 0 corrupt: 100% 20/20 [00:00<?, ?it/s]
#
# AutoAnchor: 6.04 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp4/labels.jpg...
# /content/yolov3/train.py:357: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 416 train, 416 val
# Using 2 dataloader workers
# Logging results to runs/train/exp4
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/2 [00:00<?, ?it/s]/content/yolov3/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/19       5.7G    0.06352     0.1014    0.08136        159        416:  50% 1/2 [00:06<00:06,  6.45s/it]/content/yolov3/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/19      5.73G    0.06539     0.1129     0.0815         45        416: 100% 2/2 [00:06<00:00,  3.46s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.61s/it]
#                    all         20        104      0.387      0.346       0.27      0.162
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/19      5.73G    0.05859     0.1253    0.07606         42        416: 100% 2/2 [00:00<00:00,  2.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.05it/s]
#                    all         20        104      0.418      0.442      0.315      0.186
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/19      5.73G    0.04853    0.09268    0.08469         38        416: 100% 2/2 [00:00<00:00,  3.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.82it/s]
#                    all         20        104      0.424      0.673      0.422      0.251
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/19      5.73G    0.04942    0.06579    0.07043         23        416: 100% 2/2 [00:00<00:00,  2.56it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.48it/s]
#                    all         20        104       0.33      0.962      0.746      0.414
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/19      5.73G    0.04628    0.07469    0.06083         45        416: 100% 2/2 [00:00<00:00,  3.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.21it/s]
#                    all         20        104      0.866      0.885      0.932      0.504
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/19      5.73G    0.04278    0.07982    0.04219         54        416: 100% 2/2 [00:00<00:00,  2.32it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.18it/s]
#                    all         20        104      0.872      0.942      0.952       0.55
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/19      5.73G    0.03734    0.06434     0.0265         39        416: 100% 2/2 [00:00<00:00,  2.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.24it/s]
#                    all         20        104      0.915      0.929      0.961       0.58
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/19      5.73G    0.04115    0.05551    0.01789         31        416: 100% 2/2 [00:00<00:00,  3.10it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.15it/s]
#                    all         20        104      0.893      0.962      0.969      0.604
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/19      5.73G    0.03563    0.04464   0.009072         32        416: 100% 2/2 [00:00<00:00,  2.59it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.28it/s]
#                    all         20        104      0.905      0.962      0.972      0.611
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/19      5.73G    0.03157    0.04528   0.009062         32        416: 100% 2/2 [00:00<00:00,  3.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.34it/s]
#                    all         20        104      0.909      0.965      0.973      0.613
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/19      5.73G    0.03567    0.05663   0.009848         60        416: 100% 2/2 [00:00<00:00,  3.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.14it/s]
#                    all         20        104      0.909      0.966      0.974      0.614
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/19      5.73G     0.0317    0.03876   0.005504         22        416: 100% 2/2 [00:00<00:00,  3.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.24it/s]
#                    all         20        104       0.91      0.968      0.976       0.63
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/19      5.73G    0.03309    0.04508   0.004947         37        416: 100% 2/2 [00:00<00:00,  2.63it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.52it/s]
#                    all         20        104      0.914      0.962      0.976      0.636
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/19      5.73G    0.03321     0.0519   0.005369         48        416: 100% 2/2 [00:00<00:00,  3.14it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.24it/s]
#                    all         20        104      0.927      0.978      0.982      0.635
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/19      5.73G     0.0336    0.05873    0.00548         54        416: 100% 2/2 [00:00<00:00,  3.10it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.97it/s]
#                    all         20        104      0.927       0.98      0.982      0.646
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/19      5.73G    0.03035    0.04595   0.004014         47        416: 100% 2/2 [00:00<00:00,  2.59it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.58it/s]
#                    all         20        104      0.928      0.987      0.983      0.646
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/19      5.73G    0.03246    0.04119   0.003882         35        416: 100% 2/2 [00:00<00:00,  3.63it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.29it/s]
#                    all         20        104      0.928      0.989      0.983      0.651
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/19      5.73G    0.03144    0.05713    0.00474         63        416: 100% 2/2 [00:00<00:00,  3.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.21it/s]
#                    all         20        104      0.927       0.99      0.983      0.656
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/19      5.73G    0.03352    0.05699    0.00454         65        416: 100% 2/2 [00:00<00:00,  3.30it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.15it/s]
#                    all         20        104      0.927       0.99      0.984      0.654
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/19      5.73G    0.02934    0.03417    0.00237         27        416: 100% 2/2 [00:00<00:00,  3.54it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.06it/s]
#                    all         20        104      0.925       0.99      0.984      0.641
#
# 20 epochs completed in 0.056 hours.
# Optimizer stripped from runs/train/exp4/weights/last.pt, 124.2MB
# Optimizer stripped from runs/train/exp4/weights/best.pt, 124.2MB
#
# Validating runs/train/exp4/weights/best.pt...
# Fusing layers...
# Model summary: 190 layers, 61922845 parameters, 0 gradients, 155.9 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.03it/s]
#                    all         20        104      0.927       0.99      0.983      0.655
#                 person         20        104      0.927       0.99      0.983      0.655
# Results saved to runs/train/exp4

# %% [markdown]
# Thử inference trên 1 video sử dụng model đã finetune ở trên, ta sẽ sử dụng IoU threshold cho phần NMS là 0.5, threshold cho object score là 0.6
#
# Tải video tại link sau: ***https://u.pcloud.link/publink/show?code=XZziBhVZgRqC3dfFdWL1kB1zq0py6BbrMJny***

# %%
video_url = "https://www.google.com/url?q=https%3A%2F%2Fu.pcloud.link%2Fpublink%2Fshow%3Fcode%3DXZziBhVZgRqC3dfFdWL1kB1zq0py6BbrMJny"

# !wget "https://www.google.com/url?q=https%3A%2F%2Fu.pcloud.link%2Fpublink%2Fshow%3Fcode%3DXZziBhVZgRqC3dfFdWL1kB1zq0py6BbrMJny" -O video.mp4
# Out:
# --2024-09-25 10:00:49--  https://www.google.com/url?q=https%3A%2F%2Fu.pcloud.link%2Fpublink%2Fshow%3Fcode%3DXZziBhVZgRqC3dfFdWL1kB1zq0py6BbrMJny
# Resolving www.google.com (www.google.com)... 74.125.68.103, 74.125.68.99, 74.125.68.105, ...
# Connecting to www.google.com (www.google.com)|74.125.68.103|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘video.mp4’
#
# video.mp4               [ <=>                ]   1.52K  --.-KB/s    in 0s
#
# 2024-09-25 10:00:49 (29.1 MB/s) - ‘video.mp4’ saved [1555]

# %%
# !python detect.py --weights runs/train/exp4/weights/best.pt --source /content/coconut1.mp4 --imgsz 416 --iou-thres 0.5 --conf-thres 0.6
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (2287/27017) /content/coconut1.mp4: 416x256 7 persons, 12.1ms
# video 1/1 (2288/27017) /content/coconut1.mp4: 416x256 7 persons, 12.0ms
# video 1/1 (2289/27017) /content/coconut1.mp4: 416x256 6 persons, 12.3ms
# video 1/1 (2290/27017) /content/coconut1.mp4: 416x256 6 persons, 12.1ms
# video 1/1 (2291/27017) /content/coconut1.mp4: 416x256 5 persons, 12.4ms
# video 1/1 (2292/27017) /content/coconut1.mp4: 416x256 5 persons, 12.1ms
# video 1/1 (2293/27017) /content/coconut1.mp4: 416x256 5 persons, 12.8ms
# video 1/1 (2294/27017) /content/coconut1.mp4: 416x256 5 persons, 12.3ms
# video 1/1 (2295/27017) /content/coconut1.mp4: 416x256 5 persons, 12.1ms
# video 1/1 (2296/27017) /content/coconut1.mp4: 416x256 5 persons, 12.7ms
# video 1/1 (2297/27017) /content/coconut1.mp4: 416x256 5 persons, 12.2ms
# video 1/1 (2298/27017) /content/coconut1.mp4: 416x256 3 persons, 12.1ms
# video 1/1 (2299/27017) /content/coconut1.mp4: 416x256 3 persons, 12.6ms
# video 1/1 (2300/27017) /content/coconut1.mp4: 416x256 3 persons, 12.2ms
# video 1/1 (2301/27017) /content/coconut1.mp4: 416x256 3 persons, 12.1ms
# video 1/1 (2302/27017) /content/coconut1.mp4: 416x256 3 persons, 12.7ms
# video 1/1 (2303/27017) /content/coconut1.mp4: 416x256 3 persons, 12.2ms
# video 1/1 (2304/27017) /content/coconut1.mp4: 416x256 3 persons, 12.5ms
# video 1/1 (2305/27017) /content/coconut1.mp4: 416x256 3 persons, 12.2ms
# video 1/1 (2306/27017) /content/coconut1.mp4: 416x256 3 persons, 12.1ms
# video 1/1 (2307/27017) /content/coconut1.mp4: 416x256 3 persons, 12.6ms
# video 1/1 (2308/27017) /content/coconut1.mp4: 416x256 2 persons, 12.2ms
# video 1/1 (2309/27017) /content/coconut1.mp4: 416x256 3 persons, 12.3ms
# video 1/1 (2310/27017) /content/coconut1.mp4: 416x256 2 persons, 12.6ms
# video 1/1 (2311/27017) /content/coconut1.mp4: 416x256 2 persons, 12.5ms
# video 1/1 (2312/27017) /content/coconut1.mp4: 416x256 3 persons, 12.1ms
# video 1/1 (2313/27017) /content/coconut1.mp4: 416x256 2 persons, 12.5ms
# video 1/1 (2314/27017) /content/coconut1.mp4: 416x256 3 persons, 12.2ms
# video 1/1 (2315/27017) /content/coconut1.mp4: 416x256 3 persons, 12.1ms
# video 1/1 (2316/27017) /content/coconut1.mp4: 416x256 3 persons, 12.4ms
# video 1/1 (2317/27017) /content/coconut1.mp4: 416x256 3 persons, 12.3ms
# video 1/1 (2318/27017) /content/coconut1.mp4: 416x256 3 persons, 12.1ms
# video 1/1 (2319/27017) /content/coconut1.mp4: 416x256 3 persons, 12.1ms
# video 1/1 (2320/27017) /content/coconut1.mp4: 416x256 5 persons, 12.4ms
# video 1/1 (2321/27017) /content/coconut1.mp4: 416x256 5 persons, 12.1ms
# video 1/1 (2322/27017) /content/coconut1.mp4: 416x256 5 persons, 12.1ms
# video 1/1 (2323/27017) /content/coconut1.mp4: 416x256 5 persons, 12.3ms
# video 1/1 (2324/27017) /content/coconut1.mp4: 416x256 5 persons, 12.1ms
# video 1/1 (2325/27017) /content/coconut1.mp4: 416x256 5 persons, 12.6ms
# video 1/1 (2326/27017) /content/coconut1.mp4: 416x256 5 persons, 12.9ms
# video 1/1 (2327/27017) /content/coconut1.mp4: 416x256 5 persons, 12.1ms
# video 1/1 (2328/27017) /content/coconut1.mp4: 416x256 5 persons, 12.3ms
# video 1/1 (2329/27017) /content/coconut1.mp4: 416x256 5 persons, 12.1ms
# video 1/1 (2330/27017) /content/coconut1.mp4: 416x256 5 persons, 12.3ms
# video 1/1 (2331/27017) /content/coconut1.mp4: 416x256 5 persons, 12.1ms
# video 1/1 (2332/27017) /content/coconut1.mp4: 416x256 7 persons, 12.0ms
# video 1/1 (2333/27017) /content/coconut1.mp4: 416x256 7 persons, 12.3ms
# video 1/1 (2334/27017) /content/coconut1.mp4: 416x256 7 persons, 12.1ms
# video 1/1 (2335/27017) /content/coconut1.mp4: 416x256 7 persons, 12.5ms
# video 1/1 (2336/27017) /content/coconut1.mp4: 416x256 6 persons, 12.1ms
# video 1/1 (2337/27017) /content/coconut1.mp4: 416x256 6 persons, 12.0ms
# video 1/1 (2338/27017) /content/coconut1.mp4: 416x256 6 persons, 12.4ms
# video 1/1 (2339/27017) /content/coconut1.mp4: 416x256 6 persons, 12.1ms
# video 1/1 (2340/27017) /content/coconut1.mp4: 416x256 6 persons, 12.2ms
# video 1/1 (2341/27017) /content/coconut1.mp4: 416x256 6 persons, 12.0ms
# video 1/1 (2342/27017) /content/coconut1.mp4: 416x256 5 persons, 12.4ms
# video 1/1 (2343/27017) /content/coconut1.mp4: 416x256 5 persons, 12.1ms
# video 1/1 (2344/27017) /content/coconut1.mp4: 416x256 4 persons, 12.0ms
# video 1/1 (2345/27017) /content/coconut1.mp4: 416x256 6 persons, 12.5ms
# video 1/1 (2346/27017) /content/coconut1.mp4: 416x256 6 persons, 12.1ms
# video 1/1 (2347/27017) /content/coconut1.mp4: 416x256 6 persons, 12.1ms
# video 1/1 (2348/27017) /content/coconut1.mp4: 416x256 6 persons, 12.2ms
# video 1/1 (2349/27017) /content/coconut1.mp4: 416x256 6 persons, 12.0ms
# video 1/1 (2350/27017) /content/coconut1.mp4: 416x256 6 persons, 12.4ms
# video 1/1 (2351/27017) /content/coconut1.mp4: 416x256 6 persons, 12.2ms
# video 1/1 (2352/27017) /content/coconut1.mp4: 416x256 6 persons, 12.1ms
# video 1/1 (2353/27017) /content/coconut1.mp4: 416x256 6 persons, 12.2ms
# video 1/1 (2354/27017) /content/coconut1.mp4: 416x256 6 persons, 12.1ms
# video 1/1 (2355/27017) /content/coconut1.mp4: 416x256 7 persons, 12.2ms
# video 1/1 (2356/27017) /content/coconut1.mp4: 416x256 7 persons, 12.2ms
# video 1/1 (2357/27017) /content/coconut1.mp4: 416x256 7 persons, 12.0ms
# video 1/1 (2358/27017) /content/coconut1.mp4: 416x256 7 persons, 12.6ms
# video 1/1 (2359/27017) /content/coconut1.mp4: 416x256 7 persons, 12.2ms
# video 1/1 (2360/27017) /content/coconut1.mp4: 416x256 7 persons, 12.1ms
# video 1/1 (2361/27017) /content/coconut1.mp4: 416x256 7 persons, 12.3ms
# video 1/1 (2362/27017) /content/coconut1.mp4: 416x256 8 persons, 12.1ms
# video 1/1 (2363/27017) /content/coconut1.mp4: 416x256 8 persons, 12.4ms
# video 1/1 (2364/27017) /content/coconut1.mp4: 416x256 8 persons, 12.1ms
# video 1/1 (2365/27017) /content/coconut1.mp4: 416x256 8 persons, 13.2ms
# video 1/1 (2366/27017) /content/coconut1.mp4: 416x256 8 persons, 12.2ms
# video 1/1 (2367/27017) /content/coconut1.mp4: 416x256 8 persons, 12.4ms
# video 1/1 (2368/27017) /content/coconut1.mp4: 416x256 9 persons, 12.2ms
# video 1/1 (2369/27017) /content/coconut1.mp4: 416x256 9 persons, 12.1ms
# video 1/1 (2370/27017) /content/coconut1.mp4: 416x256 9 persons, 12.4ms
# video 1/1 (2371/27017) /content/coconut1.mp4: 416x256 9 persons, 12.1ms
# video 1/1 (2372/27017) /content/coconut1.mp4: 416x256 9 persons, 12.5ms
# video 1/1 (2373/27017) /content/coconut1.mp4: 416x256 9 persons, 12.1ms
# video 1/1 (
27017) /content/coconut1.mp4: 416x256 4 persons, 12.0ms
# video 1/1 (2460/27017) /content/coconut1.mp4: 416x256 5 persons, 14.2ms
# video 1/1 (2461/27017) /content/coconut1.mp4: 416x256 5 persons, 12.8ms
# video 1/1 (2462/27017) /content/coconut1.mp4: 416x256 5 persons, 13.1ms
# video 1/1 (2463/27017) /content/coconut1.mp4: 416x256 5 persons, 13.2ms
# video 1/1 (2464/27017) /content/coconut1.mp4: 416x256 5 persons, 13.2ms
# video 1/1 (2465/27017) /content/coconut1.mp4: 416x256 6 persons, 14.2ms
# video 1/1 (2466/27017) /content/coconut1.mp4: 416x256 6 persons, 13.4ms
# video 1/1 (2467/27017) /content/coconut1.mp4: 416x256 6 persons, 13.3ms
# video 1/1 (2468/27017) /content/coconut1.mp4: 416x256 6 persons, 13.7ms
# video 1/1 (2469/27017) /content/coconut1.mp4: 416x256 5 persons, 13.2ms
# video 1/1 (2470/27017) /content/coconut1.mp4: 416x256 5 persons, 13.1ms
# video 1/1 (2471/27017) /content/coconut1.mp4: 416x256 4 persons, 13.2ms
# video 1/1 (2472/27017) /content/coconut1.mp4: 416x256 4 persons, 13.6ms
# video 1/1 (2473/27017) /content/coconut1.mp4: 416x256 5 persons, 13.6ms
# video 1/1 (2474/27017) /content/coconut1.mp4: 416x256 5 persons, 14.2ms
# video 1/1 (2475/27017) /content/coconut1.mp4: 416x256 5 persons, 13.2ms
# video 1/1 (2476/27017) /content/coconut1.mp4: 416x256 5 persons, 13.3ms
# video 1/1 (2477/27017) /content/coconut1.mp4: 416x256 5 persons, 13.8ms
# video 1/1 (2478/27017) /content/coconut1.mp4: 416x256 5 persons, 13.6ms
# video 1/1 (2479/27017) /content/coconut1.mp4: 416x256 5 persons, 13.6ms
# video 1/1 (2480/27017) /content/coconut1.mp4: 416x256 5 persons, 13.4ms
# video 1/1 (2481/27017) /content/coconut1.mp4: 416x256 5 persons, 13.4ms
# video 1/1 (2482/27017) /content/coconut1.mp4: 416x256 5 persons, 13.7ms
# video 1/1 (2483/27017) /content/coconut1.mp4: 416x256 5 persons, 13.7ms
# video 1/1 (2484/27017) /content/coconut1.mp4: 416x256 5 persons, 13.7ms
# video 1/1 (2485/27017) /content/coconut1.mp4: 416x256 5 persons, 14.7ms
# video 1/1 (2486/27017) /content/coconut1.mp4: 416x256 5 persons, 13.6ms
# video 1/1 (2487/27017) /content/coconut1.mp4: 416x256 5 persons, 14.4ms
# video 1/1 (2488/27017) /content/coconut1.mp4: 416x256 5 persons, 17.4ms
# video 1/1 (2489/27017) /content/coconut1.mp4: 416x256 5 persons, 13.7ms
# video 1/1 (2490/27017) /content/coconut1.mp4: 416x256 5 persons, 13.8ms
# video 1/1 (2491/27017) /content/coconut1.mp4: 416x256 5 persons, 14.9ms
# video 1/1 (2492/27017) /content/coconut1.mp4: 416x256 5 persons, 13.9ms
# video 1/1 (2493/27017) /content/coconut1.mp4: 416x256 5 persons, 19.0ms
# video 1/1 (2494/27017) /content/coconut1.mp4: 416x256 5 persons, 13.8ms
# video 1/1 (2495/27017) /content/coconut1.mp4: 416x256 5 persons, 14.2ms
# video 1/1 (2496/27017) /content/coconut1.mp4: 416x256 5 persons, 14.2ms
# video 1/1 (2497/27017) /content/coconut1.mp4: 416x256 5 persons, 14.2ms
# video 1/1 (2498/27017) /content/coconut1.mp4: 416x256 5 persons, 17.0ms
# video 1/1 (2499/27017) /content/coconut1.mp4: 416x256 6 persons, 14.0ms
# video 1/1 (2500/27017) /content/coconut1.mp4: 416x256 5 persons, 15.7ms
# video 1/1 (2501/27017) /content/coconut1.mp4: 416x256 5 persons, 14.3ms
# video 1/1 (2502/27017) /content/coconut1.mp4: 416x256 5 persons, 14.6ms
# video 1/1 (2503/27017) /content/coconut1.mp4: 416x256 6 persons, 14.5ms
# video 1/1 (2504/27017) /content/coconut1.mp4: 416x256 6 persons, 14.1ms
# video 1/1 (2505/27017) /content/coconut1.mp4: 416x256 6 persons, 14.1ms
# video 1/1 (2506/27017) /content/coconut1.mp4: 416x256 7 persons, 14.4ms
# video 1/1 (2507/27017) /content/coconut1.mp4: 416x256 7 persons, 14.4ms
# video 1/1 (2508/27017) /content/coconut1.mp4: 416x256 5 persons, 14.2ms
# video 1/1 (2509/27017) /content/coconut1.mp4: 416x256 5 persons, 14.2ms
# video 1/1 (2510/27017) /content/coconut1.mp4: 416x256 5 persons, 14.3ms
# video 1/1 (2511/27017) /content/coconut1.mp4: 416x256 6 persons, 14.5ms
# video 1/1 (2512/27017) /content/coconut1.mp4: 416x256 8 persons, 14.4ms
# video 1/1 (2513/27017) /content/coconut1.mp4: 416x256 7 persons, 14.3ms
# video 1/1 (2514/27017) /content/coconut1.mp4: 416x256 6 persons, 14.4ms
# video 1/1 (2515/27017) /content/coconut1.mp4: 416x256 8 persons, 14.6ms
# video 1/1 (2516/27017) /content/coconut1.mp4: 416x256 6 persons, 17.4ms
# video 1/1 (2517/27017) /content/coconut1.mp4: 416x256 7 persons, 14.5ms
# video 1/1 (2518/27017) /content/coconut1.mp4: 416x256 7 persons, 14.5ms
# video 1/1 (2519/27017) /content/coconut1.mp4: 416x256 7 persons, 14.5ms
# video 1/1 (2520/27017) /content/coconut1.mp4: 416x256 7 persons, 14.5ms
# video 1/1 (2521/27017) /content/coconut1.mp4: 416x256 6 persons, 14.5ms
# video 1/1 (2522/27017) /content/coconut1.mp4: 416x256 6 persons, 14.5ms
# video 1/1 (2523/27017) /content/coconut1.mp4: 416x256 6 persons, 14.4ms
# video 1/1 (2524/27017) /content/coconut1.mp4: 416x256 6 persons, 14.5ms
# video 1/1 (2525/27017) /content/coconut1.mp4: 416x256 6 persons, 14.8ms
# video 1/1 (2526/27017) /content/coconut1.mp4: 416x256 7 persons, 15.6ms
# video 1/1 (2527/27017) /content/coconut1.mp4: 416x256 7 persons, 18.1ms
# video 1/1 (2528/27017) /content/coconut1.mp4: 416x256 7 persons, 15.9ms
# video 1/1 (2529/27017) /content/coconut1.mp4: 416x256 8 persons, 15.1ms
# video 1/1 (2530/27017) /content/coconut1.mp4: 416x256 8 persons, 15.1ms
# video 1/1 (2531/27017) /content/coconut1.mp4: 416x256 8 persons, 14.8ms
# video 1/1 (2532/27017) /content/coconut1.mp4: 416x256 8 persons, 14.8ms
# video 1/1 (2533/27017) /content/coconut1.mp4: 416x256 8 persons, 15.2ms
# video 1/1 (2534/27017) /content/coconut1.mp4: 416x256 8 persons, 15.4ms
# video 1/1 (2535/27017) /content/coconut1.mp4: 416x256 8 persons, 15.8ms
# video 1/1 (2536/27017) /content/coconut1.mp4: 416x256 7 persons, 15.3ms
27017) /content/coconut1.mp4: 416x256 7 persons, 12.4ms
# video 1/1 (2868/27017) /content/coconut1.mp4: 416x256 7 persons, 18.1ms
# video 1/1 (2869/27017) /content/coconut1.mp4: 416x256 7 persons, 12.1ms
# video 1/1 (2870/27017) /content/coconut1.mp4: 416x256 7 persons, 12.0ms
# video 1/1 (2871/27017) /content/coconut1.mp4: 416x256 7 persons, 12.5ms
# video 1/1 (2872/27017) /content/coconut1.mp4: 416x256 7 persons, 12.2ms
# video 1/1 (2873/27017) /content/coconut1.mp4: 416x256 6 persons, 12.1ms
# video 1/1 (2874/27017) /content/coconut1.mp4: 416x256 6 persons, 12.4ms
# video 1/1 (2875/27017) /content/coconut1.mp4: 416x256 6 persons, 12.1ms
# video 1/1 (2876/27017) /content/coconut1.mp4: 416x256 6 persons, 12.4ms
# video 1/1 (2877/27017) /content/coconut1.mp4: 416x256 6 persons, 12.2ms
# video 1/1 (2878/27017) /content/coconut1.mp4: 416x256 7 persons, 12.3ms
# video 1/1 (2879/27017) /content/coconut1.mp4: 416x256 7 persons, 12.1ms
# video 1/1 (2880/27017) /content/coconut1.mp4: 416x256 6 persons, 12.1ms
# video 1/1 (2881/27017) /content/coconut1.mp4: 416x256 7 persons, 12.2ms
# video 1/1 (2882/27017) /content/coconut1.mp4: 416x256 6 persons, 12.1ms
# video 1/1 (2883/27017) /content/coconut1.mp4: 416x256 8 persons, 12.7ms
# video 1/1 (2884/27017) /content/coconut1.mp4: 416x256 8 persons, 16.8ms
# video 1/1 (2885/27017) /content/coconut1.mp4: 416x256 8 persons, 12.3ms
# video 1/1 (2886/27017) /content/coconut1.mp4: 416x256 8 persons, 12.8ms
# video 1/1 (2887/27017) /content/coconut1.mp4: 416x256 8 persons, 13.3ms
# video 1/1 (2888/27017) /content/coconut1.mp4: 416x256 8 persons, 12.1ms
# video 1/1 (2889/27017) /content/coconut1.mp4: 416x256 8 persons, 12.2ms
# video 1/1 (2890/27017) /content/coconut1.mp4: 416x256 8 persons, 12.2ms
# video 1/1 (2891/27017) /content/coconut1.mp4: 416x256 8 persons, 13.2ms
# video 1/1 (2892/27017) /content/coconut1.mp4: 416x256 7 persons, 13.7ms
# video 1/1 (2893/27017) /content/coconut1.mp4: 416x256 6 persons, 12.7ms
# video 1/1 (2894/27017) /content/coconut1.mp4: 416x256 6 persons, 12.7ms
# video 1/1 (2895/27017) /content/coconut1.mp4: 416x256 6 persons, 17.4ms
# video 1/1 (2896/27017) /content/coconut1.mp4: 416x256 6 persons, 12.0ms
# video 1/1 (2897/27017) /content/coconut1.mp4: 416x256 6 persons, 12.0ms
# video 1/1 (2898/27017) /content/coconut1.mp4: 416x256 6 persons, 12.2ms
# video 1/1 (2899/27017) /content/coconut1.mp4: 416x256 6 persons, 12.2ms
# video 1/1 (2900/27017) /content/coconut1.mp4: 416x256 6 persons, 12.1ms
# video 1/1 (2901/27017) /content/coconut1.mp4: 416x256 5 persons, 12.1ms
# video 1/1 (2902/27017) /content/coconut1.mp4: 416x256 5 persons, 12.0ms
# video 1/1 (2903/27017) /content/coconut1.mp4: 416x256 5 persons, 12.1ms
# video 1/1 (2904/27017) /content/coconut1.mp4: 416x256 5 persons, 14.8ms
# video 1/1 (2905/27017) /content/coconut1.mp4: 416x256 5 persons, 12.1ms
# video 1/1 (2906/27017) /content/coconut1.mp4: 416x256 5 persons, 12.1ms
# video 1/1 (2907/27017) /content/coconut1.mp4: 416x256 5 persons, 12.0ms
# video 1/1 (2908/27017) /content/coconut1.mp4: 416x256 4 persons, 12.2ms
# video 1/1 (2909/27017) /content/coconut1.mp4: 416x256 4 persons, 12.1ms
# video 1/1 (2910/27017) /content/coconut1.mp4: 416x256 4 persons, 12.3ms
# video 1/1 (2911/27017) /content/coconut1.mp4: 416x256 4 persons, 12.4ms
# video 1/1 (2912/27017) /content/coconut1.mp4: 416x256 4 persons, 12.6ms
# video 1/1 (2913/27017) /content/coconut1.mp4: 416x256 4 persons, 12.1ms
# video 1/1 (2914/27017) /content/coconut1.mp4: 416x256 3 persons, 13.3ms
# video 1/1 (2915/27017) /content/coconut1.mp4: 416x256 4 persons, 13.5ms
# video 1/1 (2916/27017) /content/coconut1.mp4: 416x256 4 persons, 12.5ms
# video 1/1 (2917/27017) /content/coconut1.mp4: 416x256 4 persons, 12.1ms
# video 1/1 (2918/27017) /content/coconut1.mp4: 416x256 4 persons, 12.1ms
# video 1/1 (2919/27017) /content/coconut1.mp4: 416x256 4 persons, 12.2ms
# video 1/1 (2920/27017) /content/coconut1.mp4: 416x256 4 persons, 14.4ms
# video 1/1 (2921/27017) /content/coconut1.mp4: 416x256 4 persons, 12.1ms
# video 1/1 (2922/27017) /content/coconut1.mp4: 416x256 4 persons, 12.1ms
# video 1/1 (2923/27017) /content/coconut1.mp4: 416x256 4 persons, 14.4ms
# video 1/1 (2924/27017) /content/coconut1.mp4: 416x256 4 persons, 12.0ms
# video 1/1 (2925/27017) /content/coconut1.mp4: 416x256 4 persons, 12.2ms
# video 1/1 (2926/27017) /content/coconut1.mp4: 416x256 4 persons, 12.0ms
# video 1/1 (2927/27017) /content/coconut1.mp4: 416x256 5 persons, 12.0ms
# video 1/1 (2928/27017) /content/coconut1.mp4: 416x256 5 persons, 12.7ms
# video 1/1 (2929/27017) /content/coconut1.mp4: 416x256 5 persons, 12.7ms
# video 1/1 (2930/27017) /content/coconut1.mp4: 416x256 5 persons, 12.7ms
# video 1/1 (2931/27017) /content/coconut1.mp4: 416x256 5 persons, 12.7ms
# video 1/1 (2932/27017) /content/coconut1.mp4: 416x256 5 persons, 12.7ms
# video 1/1 (2933/27017) /content/coconut1.mp4: 416x256 6 persons, 12.9ms
# video 1/1 (2934/27017) /content/coconut1.mp4: 416x256 4 persons, 16.5ms
# video 1/1 (2935/27017) /content/coconut1.mp4: 416x256 5 persons, 13.2ms
# video 1/1 (2936/27017) /content/coconut1.mp4: 416x256 5 persons, 13.6ms
# video 1/1 (2937/27017) /content/coconut1.mp4: 416x256 4 persons, 13.8ms
# video 1/1 (2938/27017) /content/coconut1.mp4: 416x256 4 persons, 13.0ms
# video 1/1 (2939/27017) /content/coconut1.mp4: 416x256 5 persons, 13.0ms
# video 1/1 (2940/27017) /content/coconut1.mp4: 416x256 5 persons, 13.0ms
# video 1/1 (2941/27017) /content/coconut1.mp4: 416x256 4 persons, 12.9ms
# video 1/1 (2942/27017) /content/coconut1.mp4: 416x256 5 persons, 13.1ms
# video 1/1 (2943/27017) /content/coconut1.mp4: 416x256 4 persons, 13.2ms
# video 1/1 (2944/27017) /content/coconut1.mp4: 416x256 4 persons, 13.3ms
# video 1/1 (2945/27017) /content/coconut1.mp4: 416x256 5 persons, 13.1ms
# video 1/1 (2946/27017) /content/coconut1.mp4: 416x256 5 persons, 13.2ms
# video 1/1 (2947/27017) /content/coconut1.mp4: 416x256 6 persons, 20.2ms
# video 1/1 (2948/27017) /content/coconut1.mp4: 416x256 6 persons, 16.9ms
# video 1/1 (2949/27017) /content/coconut1.mp4: 416x256 6 persons, 13.4ms
# video 1/1 (2950/27017) /content/coconut1.mp4: 416x256 6 persons, 13.6ms
# video 1/1 (2951/27017) /content/coconut1.mp4: 416x256 5 persons, 13.3ms
# ...
# video 1/1 (7061/27017) /content/coconut1.mp4: 416x256 3 persons, 12.3ms
# video 1/1 (7062/27017) /content/coconut1.mp4: 416x256 4 persons, 13.2ms
# video 1/1 (7063/27017) /content/coconut1.mp4: 416x256 4 persons, 12.7ms
# video 1/1 (7064/27017) /content/coconut1.mp4: 416x256 4 persons, 12.3ms
# video 1/1 (7065/27017) /content/coconut1.mp4: 416x256 5 persons, 13.2ms
# video 1/1 (7066/27017) /content/coconut1.mp4: 416x256 5 persons, 12.5ms
# video 1/1 (7067/27017) /content/coconut1.mp4: 416x256 5 persons, 12.4ms
# video 1/1 (7068/27017) /content/coconut1.mp4: 416x256 5 persons, 12.7ms
# video 1/1 (7069/27017) /content/coconut1.mp4: 416x256 5 persons, 12.3ms
# video 1/1 (7070/27017) /content/coconut1.mp4: 416x256 5 persons, 12.2ms
# video 1/1 (7071/27017) /content/coconut1.mp4: 416x256 5 persons, 12.2ms
# video 1/1 (7072/27017) /content/coconut1.mp4: 416x256 4 persons, 13.1ms
# video 1/1 (7073/27017) /content/coconut1.mp4: 416x256 4 persons, 12.5ms
# video 1/1 (7074/27017) /content/coconut1.mp4: 416x256 4 persons, 12.4ms
# video 1/1 (7075/27017) /content/coconut1.mp4: 416x256 4 persons, 13.0ms
# video 1/1 (7076/27017) /content/coconut1.mp4: 416x256 4 persons, 12.4ms
# video 1/1 (7077/27017) /content/coconut1.mp4: 416x256 4 persons, 12.4ms
# video 1/1 (7078/27017) /content/coconut1.mp4: 416x256 4 persons, 12.2ms
# video 1/1 (7079/27017) /content/coconut1.mp4: 416x256 4 persons, 12.3ms
# video 1/1 (7080/27017) /content/coconut1.mp4: 416x256 4 persons, 15.7ms
# video 1/1 (7081/27017) /content/coconut1.mp4: 416x256 4 persons, 12.6ms
# video 1/1 (7082/27017) /content/coconut1.mp4: 416x256 5 persons, 12.2ms
# video 1/1 (7083/27017) /content/coconut1.mp4: 416x256 5 persons, 12.4ms
# video 1/1 (7084/27017) /content/coconut1.mp4: 416x256 6 persons, 12.9ms
# video 1/1 (7085/27017) /content/coconut1.mp4: 416x256 6 persons, 12.3ms
# video 1/1 (7086/27017) /content/coconut1.mp4: 416x256 6 persons, 13.1ms
# video 1/1 (7087/27017) /content/coconut1.mp4: 416x256 6 persons, 12.3ms
# video 1/1 (7088/27017) /content/coconut1.mp4: 416x256 7 persons, 12.7ms
# video 1/1 (7089/27017) /content/coconut1.mp4: 416x256 7 persons, 13.8ms
# video 1/1 (7090/27017) /content/coconut1.mp4: 416x256 7 persons, 12.7ms
# video 1/1 (7091/27017) /content/coconut1.mp4: 416x256 7 persons, 12.2ms
# video 1/1 (7092/27017) /content/coconut1.mp4: 416x256 7 persons, 13.1ms
# video 1/1 (7093/27017) /content/coconut1.mp4: 416x256 7 persons, 12.5ms
# video 1/1 (7094/27017) /content/coconut1.mp4: 416x256 7 persons, 12.5ms
# video 1/1 (7095/27017) /content/coconut1.mp4: 416x256 7 persons, 12.6ms
# video 1/1 (7096/27017) /content/coconut1.mp4: 416x256 7 persons, 12.2ms
# video 1/1 (7097/27017) /content/coconut1.mp4: 416x256 7 persons, 13.0ms
# video 1/1 (7098/27017) /content/coconut1.mp4: 416x256 7 persons, 12.4ms
# video 1/1 (7099/27017) /content/coconut1.mp4: 416x256 8 persons, 12.5ms
# video 1/1 (7100/27017) /content/coconut1.mp4: 416x256 8 persons, 12.3ms
# video 1/1 (7101/27017) /content/coconut1.mp4: 416x256 8 persons, 12.7ms
# video 1/1 (7102/27017) /content/coconut1.mp4: 416x256 8 persons, 12.2ms
# video 1/1 
27017) /content/coconut1.mp4: 416x256 6 persons, 12.4ms
# video 1/1 (7204/27017) /content/coconut1.mp4: 416x256 7 persons, 12.2ms
# video 1/1 (7205/27017) /content/coconut1.mp4: 416x256 7 persons, 12.6ms
# video 1/1 (7206/27017) /content/coconut1.mp4: 416x256 6 persons, 12.2ms
# video 1/1 (7207/27017) /content/coconut1.mp4: 416x256 6 persons, 13.0ms
# video 1/1 (7208/27017) /content/coconut1.mp4: 416x256 7 persons, 12.7ms
# video 1/1 (7209/27017) /content/coconut1.mp4: 416x256 7 persons, 12.6ms
# video 1/1 (7210/27017) /content/coconut1.mp4: 416x256 6 persons, 12.4ms
# video 1/1 (7211/27017) /content/coconut1.mp4: 416x256 6 persons, 12.2ms
# video 1/1 (7212/27017) /content/coconut1.mp4: 416x256 6 persons, 12.9ms
# video 1/1 (7213/27017) /content/coconut1.mp4: 416x256 6 persons, 12.2ms
# video 1/1 (7214/27017) /content/coconut1.mp4: 416x256 6 persons, 12.9ms
# video 1/1 (7215/27017) /content/coconut1.mp4: 416x256 6 persons, 12.3ms
# video 1/1 (7216/27017) /content/coconut1.mp4: 416x256 6 persons, 12.6ms
# video 1/1 (7217/27017) /content/coconut1.mp4: 416x256 6 persons, 12.5ms
# video 1/1 (7218/27017) /content/coconut1.mp4: 416x256 6 persons, 12.2ms
# video 1/1 (7219/27017) /content/coconut1.mp4: 416x256 6 persons, 12.5ms
# video 1/1 (7220/27017) /content/coconut1.mp4: 416x256 6 persons, 13.1ms
# video 1/1 (7221/27017) /content/coconut1.mp4: 416x256 6 persons, 12.7ms
# video 1/1 (7222/27017) /content/coconut1.mp4: 416x256 5 persons, 12.3ms
# video 1/1 (7223/27017) /content/coconut1.mp4: 416x256 5 persons, 12.6ms
# video 1/1 (7224/27017) /content/coconut1.mp4: 416x256 5 persons, 12.2ms
# video 1/1 (7225/27017) /content/coconut1.mp4: 416x256 5 persons, 12.1ms
# video 1/1 (7226/27017) /content/coconut1.mp4: 416x256 5 persons, 13.4ms
# video 1/1 (7227/27017) /content/coconut1.mp4: 416x256 5 persons, 13.8ms
# video 1/1 (7228/27017) /content/coconut1.mp4: 416x256 5 persons, 12.1ms
# video 1/1 (7229/27017) /content/coconut1.mp4: 416x256 6 persons, 16.8ms
# video 1/1 (7230/27017) /content/coconut1.mp4: 416x256 6 persons, 14.3ms
# video 1/1 (7231/27017) /content/coconut1.mp4: 416x256 6 persons, 12.2ms
# video 1/1 (7232/27017) /content/coconut1.mp4: 416x256 5 persons, 12.1ms
# video 1/1 (7233/27017) /content/coconut1.mp4: 416x256 5 persons, 12.1ms
# video 1/1 (7234/27017) /content/coconut1.mp4: 416x256 5 persons, 13.0ms
# video 1/1 (7235/27017) /content/coconut1.mp4: 416x256 5 persons, 12.0ms
# video 1/1 (7236/27017) /content/coconut1.mp4: 416x256 5 persons, 16.3ms
# Traceback (most recent call last):
#   File "/content/yolov3/detect.py", line 421, in <module>
#     main(opt)
#   File "/content/yolov3/detect.py", line 416, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/yolov3/detect.py", line 197, in run
#     pred = model(im, augment=augment, visualize=visualize)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/content/yolov3/models/common.py", line 657, in forward
#     y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/content/yolov3/models/yolo.py", line 248, in forward
#     return self._forward_once(x, profile, visualize)  # single-scale inference, train
#   File "/content/yolov3/models/yolo.py", line 149, in _forward_once
#     x = m(x)  # run
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py", line 219, in forward
#     input = module(input)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/content/yolov3/models/common.py", line 167, in forward
#     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/content/yolov3/models/common.py", line 81, in forward_fuse
#     return self.act(self.conv(x))
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py", line 458, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py", line 454, in _conv_forward
#     return F.conv2d(input, weight, bias, self.stride,
# KeyboardInterrupt

# %% [markdown]
# ## Cách 2: Tự cấu hình lại các tham số
#
# Để làm chủ việc training model, ta có thể tự thay đổi các tham số để phù hợp với từng bộ dữ liệu khác nhau. Bài toán coconut detection khá đơn giản, vì vậy cách sử dụng pretrained ở trên đã cho kết quả tốt, tuy nhiên với nhiều bài toán phức tạp hơn, ta sẽ cần thay đổi các tham số sao cho phù hợp. Ở đây ta sẽ cấu hình 2 phần chính:
#
#
# *   Anchor boxes và Model architecture
# *   Model hyper parameters

# %% [markdown]
# ### Anchor boxes và Model architecture
#
# - Hãy quan sát file yolov3/models/yolov3.yaml. Ta sẽ tạo file yolov3/models/coconut.yaml để tự cấu hình.
# - Phần architecture gồm backbone và head bạn có thể tự thay đổi ở nhà để thử nghiệm, trong bài thực hành này ta sẽ giữ nguyên architecture của yolov3
# - Tham số _nc_ là số lượng lớp của bài toán, ta cần thay đổi cho phù hợp (ở cách train 1 ở trên, ta không chỉ định file config yaml này thì model tự hiểu lấy tham số _nc_ trong file data/coconut.yaml)
# - Tham số anchors: Trong nhiều bài toán phức tạp, việc tìm anchor boxes mới là cần thiết. Bạn có thể tham khảo repo sau: <a href=https://github.com/decanbay/YOLOv3-Calculate-Anchor-Boxes>https://github.com/decanbay/YOLOv3-Calculate-Anchor-Boxes </a>. Hãy thử thay đổi anchor box của mô hình như sau:
#
# ```
# P3/8: 77,34, 84,50, 87,70
#
# P4/16: 100,43, 107,59, 117,75
#
# P5/32: 128,50, 142,66, 153,87
# ```

# %%
# !cd /content/yolov3/models/

# %% [markdown]
# ### Model hyper parameter
#
# Các siêu tham số cho quá trình huấn luyện mô hình được lưu ở các file yaml trong thư mục yolov3/data/hyps. Hãy quan sát file hyp.scratch.yaml và thay đổi theo ý muốn của bạn

# %% [markdown]
# ### Training model

# %%
# !python train.py --img 416 --batch 16 --epochs 20 --data data/coconut.yaml --weights yolov3.pt --cfg models/yolov3.yaml --hyp data/hyps/hyp.scratch-high.yaml
# Out:
# 2024-09-25 10:06:32.803479: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-25 10:06:32.823694: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-25 10:06:32.829902: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov3.pt, cfg=models/yolov3.yaml, data=data/coconut.yaml, hyp=data/hyps/hyp.scratch-high.yaml, epochs=20, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv3 is out of date by 2852 commits. Use 'git pull ultralytics master' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv3 🚀 v9.6.0-227-g8882dca3 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.3, cls_pw=1.0, obj=0.7, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.1, copy_paste=0.1
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv3 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
#
#                  from  n    params  module                                  arguments
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 1]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     20672  models.common.Bottleneck                [64, 64]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    164608  models.common.Bottleneck                [128, 128]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  8   2627584  models.common.Bottleneck                [256, 256]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  8  10498048  models.common.Bottleneck                [512, 512]
#   9                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#  10                -1  4  20983808  models.common.Bottleneck                [1024, 1024]
#  11                -1  1   5245952  models.common.Bottleneck                [1024, 1024, False]
#  12                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  13                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 1]
#  14                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  15                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 1]
#  16                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  17                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  18           [-1, 8]  1         0  models.common.Concat                    [1]
#  19                -1  1   1377792  models.common.Bottleneck                [768, 512, False]
#  20                -1  1   1312256  models.common.Bottleneck                [512, 512, False]
#  21                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  22                -1  1   1180672  models.common.Conv                      [256, 512, 3, 1]
#  23                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  24                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  25           [-1, 6]  1         0  models.common.Concat                    [1]
#  26                -1  1    344832  models.common.Bottleneck                [384, 256, False]
#  27                -1  2    656896  models.common.Bottleneck                [256, 256, False]
#  28      [27, 22, 15]  1    457725  models.yolo.Detect                      [80, [[77, 34, 84, 50, 87, 70], [100, 43, 107, 59, 117, 75], [128, 50, 142, 66, 153, 87]], [256, 512, 1024]]
# yolov3 summary: 262 layers, 61949149 parameters, 61949149 gradients, 156.6 GFLOPs
#
# Transferred 438/439 items from yolov3.pt
# /content/yolov3/models/common.py:860: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 72 weight(decay=0.0), 75 weight(decay=0.0005), 75 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/datasets/labels.cache... 20 images, 0 backgrounds, 0 corrupt: 100% 20/20 [00:00<?, ?it/s]
# val: Scanning /content/datasets/labels.cache... 20 images, 0 backgrounds, 0 corrupt: 100% 20/20 [00:00<?, ?it/s]
#
# AutoAnchor: 8.82 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp5/labels.jpg...
# /content/yolov3/train.py:357: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 416 train, 416 val
# Using 2 dataloader workers
# Logging results to runs/train/exp5
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/2 [00:00<?, ?it/s]/content/yolov3/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/19       5.7G     0.1135    0.03234    0.05241        167        416:  50% 1/2 [00:06<00:06,  6.77s/it]/content/yolov3/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/19      5.73G     0.1163    0.04736    0.05044         76        416: 100% 2/2 [00:07<00:00,  3.72s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.32it/s]
#                    all         20        104     0.0612      0.144     0.0355    0.00707
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/19      5.73G     0.1125    0.03894    0.05612         42        416: 100% 2/2 [00:00<00:00,  2.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.90it/s]
#                    all         20        104     0.0556      0.163     0.0341     0.0085
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/19      5.73G     0.1054    0.05495    0.04974         28        416: 100% 2/2 [00:00<00:00,  2.32it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.60it/s]
#                    all         20        104     0.0698      0.298     0.0477     0.0141
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/19      5.73G     0.1083    0.05058    0.04097         63        416: 100% 2/2 [00:00<00:00,  2.86it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.73it/s]
#                    all         20        104     0.0703        0.5     0.0625      0.014
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/19      5.73G     0.1054    0.03859    0.03045         54        416: 100% 2/2 [00:00<00:00,  2.44it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.65it/s]
#                    all         20        104      0.129       0.24      0.114      0.028
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/19      5.73G     0.1029     0.0431    0.02225         78        416: 100% 2/2 [00:00<00:00,  2.99it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.39it/s]
#                    all         20        104      0.197        0.5      0.188     0.0539
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/19      5.73G      0.095    0.03422    0.01439         24        416: 100% 2/2 [00:00<00:00,  2.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.11it/s]
#                    all         20        104      0.231       0.74      0.289        0.1
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/19      5.73G    0.09012    0.03946    0.01408         26        416: 100% 2/2 [00:00<00:00,  2.57it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.29it/s]
#                    all         20        104      0.345      0.606      0.373      0.156
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/19      5.73G    0.08755     0.0277   0.005824         53        416: 100% 2/2 [00:00<00:00,  3.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.35it/s]
#                    all         20        104      0.386      0.663      0.441      0.201
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/19      5.73G    0.09041    0.04839    0.01032         52        416: 100% 2/2 [00:00<00:00,  3.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.41it/s]
#                    all         20        104      0.447      0.668      0.509      0.256
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/19      5.73G    0.08705     0.0481    0.00799         48        416: 100% 2/2 [00:00<00:00,  2.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.86it/s]
#                    all         20        104      0.515      0.695      0.588      0.302
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/19      5.73G    0.08057    0.03853   0.005805         54        416: 100% 2/2 [00:00<00:00,  3.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.29it/s]
#                    all         20        104      0.534      0.727       0.65      0.354
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/19      5.73G    0.07944    0.03178   0.004231         31        416: 100% 2/2 [00:00<00:00,  3.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.32it/s]
#                    all         20        104      0.547      0.712      0.708       0.39
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/19      5.73G    0.08086    0.04359   0.006329         57        416: 100% 2/2 [00:00<00:00,  3.20it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.44it/s]
#                    all         20        104      0.599      0.712      0.749      0.432
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/19      5.73G    0.07976    0.03415     0.0048         50        416: 100% 2/2 [00:00<00:00,  3.01it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.97it/s]
#                    all         20        104      0.607      0.721      0.779      0.458
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/19      5.73G    0.07512    0.03132    0.00399         39        416: 100% 2/2 [00:00<00:00,  3.30it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.21it/s]
#                    all         20        104      0.641      0.721        0.8      0.479
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/19      5.73G    0.07612     0.0291   0.003705         68        416: 100% 2/2 [00:00<00:00,  2.48it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.21it/s]
#                    all         20        104      0.666      0.721      0.814      0.493
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/19      5.73G    0.07454    0.02977   0.002881         48        416: 100% 2/2 [00:00<00:00,  3.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.01it/s]
#                    all         20        104       0.73       0.74      0.843      0.513
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/19      5.73G    0.07592    0.03108   0.003406         49        416: 100% 2/2 [00:00<00:00,  2.55it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.67it/s]
#                    all         20        104      0.729      0.769      0.869      0.533
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/19      5.73G    0.06989    0.03888   0.004134         31        416: 100% 2/2 [00:00<00:00,  3.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.42it/s]
#                    all         20        104      0.789      0.808      0.901      0.557
#
# 20 epochs completed in 0.044 hours.
# Optimizer stripped from runs/train/exp5/weights/last.pt, 124.2MB
# Optimizer stripped from runs/train/exp5/weights/best.pt, 124.2MB
#
# Validating runs/train/exp5/weights/best.pt...
# Fusing layers...
# yolov3 summary: 190 layers, 61922845 parameters, 0 gradients, 155.9 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.67it/s]
#                    all         20        104      0.791      0.808      0.901      0.558
#                 person         20        104      0.791      0.808      0.901      0.558
# Results saved to runs/train/exp5

# %% [markdown]
# # 5. Làm chủ pipeline inference model đã train
#
# Ở phần trên chúng ta sử dụng file detect.py để infer mô hình đã huấn luyện, ở phần này chúng ta sẽ dựa vào file detect.py, viết 1 hàm detector ngắn gọn, nhận vào 1 ảnh, trả lại tọa độ các bounding box của object. Việc viết hàm này sẽ giúp phần lập trình thuật toán tracking dễ dàng hơn trong các buổi sau

# %%
import os
import sys
import cv2
import torch
import torch.backends.cudnn as cudnn
import numpy as np

from models.common import DetectMultiBackend
from utils.dataloaders import IMG_FORMATS, VID_FORMATS, LoadImages, LoadStreams
from utils.general import (LOGGER, check_file, check_img_size, check_imshow, check_requirements, colorstr,
                           increment_path, non_max_suppression, print_args, scale_boxes, strip_optimizer, xyxy2xywh)
from utils.plots import Annotator, colors, save_one_box
from utils.torch_utils import select_device, time_sync
from utils.augmentations import letterbox

class YOLO():
  def __init__(self):
    self.img_size = [416, 416]
    self.model_path = 'runs/train/exp5/weights/best.pt'
    self.iou_threshold = 0.5
    self.conf_threshold = 0.6
    self.device = 'cpu'
    self.device = select_device(self.device)

    # Initial model
    self.model = self.load_models()
    self.stride = self.model.stride
    self.classes = self.model.names
    print(self.model, self.stride)

  def load_models(self):
    model = DetectMultiBackend(self.model_path, device=self.device)
    model.model.float()
    # Warmup
    model(torch.zeros(1, 3, *self.img_size).to(self.device).type_as(next(model.model.parameters())))
    return model

  def preprocess_image(self, image):
    image = letterbox(image, self.img_size, stride=self.stride)[0]
    image = image.transpose((2, 0, 1))[::-1]  # HWC to CHW, BGR to RGB
    image = np.ascontiguousarray(image)

    return image

  def detect(self, image):
    im = np.array([self.preprocess_image(image)])
    im = torch.from_numpy(im).to(self.device)
    im = im.float() / 255.0
    pred = self.model(im)
    pred = non_max_suppression(pred, self.conf_threshold, self.iou_threshold)

    original_image = image.copy()
    centers = []
    bboxes = []
    obj_type = []

    for i, det in enumerate(pred):
      det[:, :4] = scale_boxes(im.shape[2:], det[:, :4], image.shape).round()

      for *xyxy, conf, cls in reversed(det):
        xyxy = [float(a) for a in xyxy]
        bboxes.append(np.array(xyxy))

        x_center = (xyxy[0] + xyxy[2]) / 2
        y_center = (xyxy[1] + xyxy[3]) / 2
        centroid = np.array([[x_center], [y_center]])
        centers.append(np.round(centroid))

        predicted_class = self.classes[int(cls)]
        obj_type.append(predicted_class)

    return original_image, centers, bboxes, obj_type



if __name__ == "__main__":
  import matplotlib.pyplot as plt

  image = cv2.imread('/content/datasets/images/5.png')
  print(image.shape)
  detector = YOLO()
  original_image, centers, bboxes, obj_type = detector.detect(image)
  print(bboxes)
  print(obj_type)
  print(centers)
  plt.imshow(original_image)
  plt.show()
# Out:
# YOLOv3 🚀 v9.6.0-227-g8882dca3 Python-3.10.12 torch-2.4.1+cu121 CPU
#
# Fusing layers...
# (1280, 720, 3)
# yolov3 summary: 190 layers, 61922845 parameters, 0 gradients, 155.9 GFLOPs
# DetectMultiBackend(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (3): Conv(
#         (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (4): Sequential(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#         (1): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#       (5): Conv(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (6): Sequential(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#         (1): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#         (2): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#         (3): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#         (4): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#         (5): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#         (6): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#         (7): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#       (7): Conv(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (8): Sequential(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#         (1): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#         (2): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#         (3): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#         (4): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#         (5): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#         (6): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#         (7): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#       (9): Conv(
#         (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (10): Sequential(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#         (1): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#         (2): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#         (3): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#       (11): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (12): Conv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (13): Conv(
#         (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (14): Conv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (15): Conv(
#         (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (16): Conv(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (17): Upsample(scale_factor=2.0, mode='nearest')
#       (18): Concat()
#       (19): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(768, 256, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (20): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (21): Conv(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (22): Conv(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (23): Conv(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (24): Upsample(scale_factor=2.0, mode='nearest')
#       (25): Concat()
#       (26): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (27): Sequential(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#         (1): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#       (28): Detect(
#         (m): ModuleList(
#           (0): Conv2d(256, 255, kernel_size=(1, 1), stride=(1, 1))
#           (1): Conv2d(512, 255, kernel_size=(1, 1), stride=(1, 1))
#           (2): Conv2d(1024, 255, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#     )
#   )
# ) 32
# [array([        302,           0,         444,          93]), array([        283,         160,         406,         294]), array([        371,          89,         503,         207]), array([        294,         494,         714,         644]), array([        163,         186,         354,         361]), array([        414,         201,         538,         326]), array([        401,         489,         611,         646]), array([        420,         645,         704,         868])]
# ['person', 'person', 'person', 'person', 'person', 'person', 'person', 'person']
# [array([[        373],
#        [         46]]), array([[        344],
#        [        227]]), array([[        437],
#        [        148]]), array([[        504],
#        [        569]]), array([[        258],
#        [        274]]), array([[        476],
#        [        264]]), array([[        506],
#        [        568]]), array([[        562],
#        [        756]])]

# %%
print(original_image.shape)
print(type(original_image))
plt.imshow(original_image, cmap='gray')
plt.show()
# Out:
# (1280, 720, 3)
# <class 'numpy.ndarray'>
